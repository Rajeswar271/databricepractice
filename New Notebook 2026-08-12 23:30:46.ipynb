# %%
dbutils.help()
dbutils.secrets.help()
dbutils.secrets.listScopes()
dbutils.secrets.list("practicescope")

# %%
dbutils.secrets.get(scope="practicescope", key="clientid")
dbutils.secrets.get(scope="practicescope", key="clientpassword")

# %%
spark.conf.set(
    "fs.azure.account.auth.type.practicestorageacount.dfs.core.windows.net",
    "OAuth"
)

# %%
spark.conf.set(
    "fs.azure.account.oauth.provider.type.practicestorageacount.dfs.core.windows.net",
    "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider"
)

# %%
spark.conf.set(
    "fs.azure.account.oauth.provider.type.practicestorageacount.dfs.core.windows.net",
    "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider"
)

# %%
spark.conf.set(
    "fs.azure.account.oauth2.client.id.practicestorageacount.dfs.core.windows.net",
    dbutils.secrets.get(scope="practicescope", key="clientid")
)

# %%
spark.conf.set(
    "fs.azure.account.oauth2.client.secret.practicestorageacount.dfs.core.windows.net",
    dbutils.secrets.get(scope="practicescope", key="clientpassword")
)

# %%
spark.conf.set(
    "fs.azure.account.oauth2.client.endpoint.practicestorageacount.dfs.core.windows.net",
    "https://login.microsoftonline.com/bda11e34-4864-4eb6-82cb-acbfb3913d55/oauth2/v2.0/token"
)

# %%
   

df = spark.read.format("csv").option("header","true").option("inferSchema","true").load(
    "abfss://bronze@practicestorageacount.dfs.core.windows.net/"
)
display(df)
